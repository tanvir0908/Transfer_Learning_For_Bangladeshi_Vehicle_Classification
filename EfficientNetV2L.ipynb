# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.models import Model
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, BatchNormalization, Conv2D, Dense, Dropout, Flatten, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# %%
train_dataset_path = '/content/drive/MyDrive/Poribohon-BD/train/'
validation_dataset_path = '/content/drive/MyDrive/Poribohon-BD/validation/'

# %%
IMG_WIDTH = 150
IMG_HEIGHT = 150
BATCH_SIZE = 32

# %%
train_datagen = ImageDataGenerator(rescale=1.0/255)
train_generator = train_datagen.flow_from_directory(train_dataset_path,
                                                   target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                   batch_size=BATCH_SIZE,
                                                   class_mode='categorical',
                                                   shuffle=True)
# Out:
# Found 7271 images belonging to 16 classes.

# %%
validation_datagen = ImageDataGenerator(rescale=1.0/255)
validation_generator = validation_datagen.flow_from_directory(validation_dataset_path,
                                                             target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                             batch_size=BATCH_SIZE,
                                                             class_mode='categorical',
                                                             shuffle=True)
# Out:
# Found 873 images belonging to 16 classes.

# %%
labels = {value: key for key, value in train_generator.class_indices.items()}

print("Label Mappings for classes present in the training and validation datasets\n")
for key, value in labels.items():
    print(f"{key} : {value}")
# Out:
# Label Mappings for classes present in the training and validation datasets
#
# 0 : Bicycle
# 1 : Bike
# 2 : Boat
# 3 : Bus
# 4 : Car
# 5 : Cng
# 6 : Easy-bike
# 7 : Horse-cart
# 8 : Launch
# 9 : Leguna
# 10 : Multi-class Vehicles
# 11 : Rickshaw
# 12 : Tractor
# 13 : Truck
# 14 : Van
# 15 : Wheelbarrow

# %%
image_size = [150,150]
ef_net_v2l = tf.keras.applications.EfficientNetV2L(input_shape = image_size+[3],weights='imagenet',include_top = False)
ef_net_v2l.output
for layer in ef_net_v2l.layers :
  layer.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-l_notop.h5
# 473178112/473176280 [==============================] - 3s 0us/step
# 473186304/473176280 [==============================] - 3s 0us/step

# %%
x = Flatten()(ef_net_v2l.output)
prediction = Dense(16,activation="softmax")(x)
model = Model(inputs=ef_net_v2l.input,outputs=prediction)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 150, 150, 3  0           []
#                                 )]
#
#  rescaling (Rescaling)          (None, 150, 150, 3)  0           ['input_1[0][0]']
#
#  stem_conv (Conv2D)             (None, 75, 75, 32)   864         ['rescaling[0][0]']
#
#  stem_bn (BatchNormalization)   (None, 75, 75, 32)   128         ['stem_conv[0][0]']
#
#  stem_activation (Activation)   (None, 75, 75, 32)   0           ['stem_bn[0][0]']
#
#  block1a_project_conv (Conv2D)  (None, 75, 75, 32)   9216        ['stem_activation[0][0]']
#
#  block1a_project_bn (BatchNorma  (None, 75, 75, 32)  128         ['block1a_project_conv[0][0]']
#  lization)
#
#  block1a_project_activation (Ac  (None, 75, 75, 32)  0           ['block1a_project_bn[0][0]']
#  tivation)
#
#  block1a_add (Add)              (None, 75, 75, 32)   0           ['block1a_project_activation[0][0
#                                                                  ]',
#                                                                   'stem_activation[0][0]']
#
#  block1b_project_conv (Conv2D)  (None, 75, 75, 32)   9216        ['block1a_add[0][0]']
#
#  block1b_project_bn (BatchNorma  (None, 75, 75, 32)  128         ['block1b_project_conv[0][0]']
#  lization)
#
#  block1b_project_activation (Ac  (None, 75, 75, 32)  0           ['block1b_project_bn[0][0]']
#  tivation)
#
#  block1b_add (Add)              (None, 75, 75, 32)   0           ['block1b_project_activation[0][0
#                                                                  ]',
#                                                                   'block1a_add[0][0]']
#
#  block1c_project_conv (Conv2D)  (None, 75, 75, 32)   9216        ['block1b_add[0][0]']
#
#  block1c_project_bn (BatchNorma  (None, 75, 75, 32)  128         ['block1c_project_conv[0][0]']
#  lization)
#
#  block1c_project_activation (Ac  (None, 75, 75, 32)  0           ['block1c_project_bn[0][0]']
#  tivation)
#
#  block1c_add (Add)              (None, 75, 75, 32)   0           ['block1c_project_activation[0][0
#                                                                  ]',
#                                                                   'block1b_add[0][0]']
#
#  block1d_project_conv (Conv2D)  (None, 75, 75, 32)   9216        ['block1c_add[0][0]']
#
#  block1d_project_bn (BatchNorma  (None, 75, 75, 32)  128         ['block1d_project_conv[0][0]']
#  lization)
#
#  block1d_project_activation (Ac  (None, 75, 75, 32)  0           ['block1d_project_bn[0][0]']
#  tivation)
#
#  block1d_add (Add)              (None, 75, 75, 32)   0           ['block1d_project_activation[0][0
#                                                                  ]',
#                                                                   'block1c_add[0][0]']
#
#  block2a_expand_conv (Conv2D)   (None, 38, 38, 128)  36864       ['block1d_add[0][0]']
#
#  block2a_expand_bn (BatchNormal  (None, 38, 38, 128)  512        ['block2a_expand_conv[0][0]']
#  ization)
#
#  block2a_expand_activation (Act  (None, 38, 38, 128)  0          ['block2a_expand_bn[0][0]']
#  ivation)
#
#  block2a_project_conv (Conv2D)  (None, 38, 38, 64)   8192        ['block2a_expand_activation[0][0]
#                                                                  ']
#
#  block2a_project_bn (BatchNorma  (None, 38, 38, 64)  256         ['block2a_project_conv[0][0]']
#  lization)
#
#  block2b_expand_conv (Conv2D)   (None, 38, 38, 256)  147456      ['block2a_project_bn[0][0]']
#
#  block2b_expand_bn (BatchNormal  (None, 38, 38, 256)  1024       ['block2b_expand_conv[0][0]']
#  ization)
#
#  block2b_expand_activation (Act  (None, 38, 38, 256)  0          ['block2b_expand_bn[0][0]']
#  ivation)
#
#  block2b_project_conv (Conv2D)  (None, 38, 38, 64)   16384       ['block2b_expand_activation[0][0]
#                                                                  ']
#
#  block2b_project_bn (BatchNorma  (None, 38, 38, 64)  256         ['block2b_project_conv[0][0]']
#  lization)
#
#  block2b_add (Add)              (None, 38, 38, 64)   0           ['block2b_project_bn[0][0]',
#                                                                   'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, 38, 38, 256)  147456      ['block2b_add[0][0]']
#
#  block2c_expand_bn (BatchNormal  (None, 38, 38, 256)  1024       ['block2c_expand_conv[0][0]']
#  ization)
#
#  block2c_expand_activation (Act  (None, 38, 38, 256)  0          ['block2c_expand_bn[0][0]']
#  ivation)
#
#  block2c_project_conv (Conv2D)  (None, 38, 38, 64)   16384       ['block2c_expand_activation[0][0]
#                                                                  ']
#
#  block2c_project_bn (BatchNorma  (None, 38, 38, 64)  256         ['block2c_project_conv[0][0]']
#  lization)
#
#  block2c_add (Add)              (None, 38, 38, 64)   0           ['block2c_project_bn[0][0]',
#                                                                   'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2D)   (None, 38, 38, 256)  147456      ['block2c_add[0][0]']
#
#  block2d_expand_bn (BatchNormal  (None, 38, 38, 256)  1024       ['block2d_expand_conv[0][0]']
#  ization)
#
#  block2d_expand_activation (Act  (None, 38, 38, 256)  0          ['block2d_expand_bn[0][0]']
#  ivation)
#
#  block2d_project_conv (Conv2D)  (None, 38, 38, 64)   16384       ['block2d_expand_activation[0][0]
#                                                                  ']
#
#  block2d_project_bn (BatchNorma  (None, 38, 38, 64)  256         ['block2d_project_conv[0][0]']
#  lization)
#
#  block2d_add (Add)              (None, 38, 38, 64)   0           ['block2d_project_bn[0][0]',
#                                                                   'block2c_add[0][0]']
#
#  block2e_expand_conv (Conv2D)   (None, 38, 38, 256)  147456      ['block2d_add[0][0]']
#
#  block2e_expand_bn (BatchNormal  (None, 38, 38, 256)  1024       ['block2e_expand_conv[0][0]']
#  ization)
#
#  block2e_expand_activation (Act  (None, 38, 38, 256)  0          ['block2e_expand_bn[0][0]']
#  ivation)
#
#  block2e_project_conv (Conv2D)  (None, 38, 38, 64)   16384       ['block2e_expand_activation[0][0]
#                                                                  ']
#
#  block2e_project_bn (BatchNorma  (None, 38, 38, 64)  256         ['block2e_project_conv[0][0]']
#  lization)
#
#  block2e_add (Add)              (None, 38, 38, 64)   0           ['block2e_project_bn[0][0]',
#                                                                   'block2d_add[0][0]']
#
#  block2f_expand_conv (Conv2D)   (None, 38, 38, 256)  147456      ['block2e_add[0][0]']
#
#  block2f_expand_bn (BatchNormal  (None, 38, 38, 256)  1024       ['block2f_expand_conv[0][0]']
#  ization)
#
#  block2f_expand_activation (Act  (None, 38, 38, 256)  0          ['block2f_expand_bn[0][0]']
#  ivation)
#
#  block2f_project_conv (Conv2D)  (None, 38, 38, 64)   16384       ['block2f_expand_activation[0][0]
#                                                                  ']
#
#  block2f_project_bn (BatchNorma  (None, 38, 38, 64)  256         ['block2f_project_conv[0][0]']
#  lization)
#
#  block2f_add (Add)              (None, 38, 38, 64)   0           ['block2f_project_bn[0][0]',
#                                                                   'block2e_add[0][0]']
#
#  block2g_expand_conv (Conv2D)   (None, 38, 38, 256)  147456      ['block2f_add[0][0]']
#
#  block2g_expand_bn (BatchNormal  (None, 38, 38, 256)  1024       ['block2g_expand_conv[0][0]']
#  ization)
#
#  block2g_expand_activation (Act  (None, 38, 38, 256)  0          ['block2g_expand_bn[0][0]']
#  ivation)
#
#  block2g_project_conv (Conv2D)  (None, 38, 38, 64)   16384       ['block2g_expand_activation[0][0]
#                                                                  ']
#
#  block2g_project_bn (BatchNorma  (None, 38, 38, 64)  256         ['block2g_project_conv[0][0]']
#  lization)
#
#  block2g_add (Add)              (None, 38, 38, 64)   0           ['block2g_project_bn[0][0]',
#                                                                   'block2f_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 19, 19, 256)  147456      ['block2g_add[0][0]']
#
#  block3a_expand_bn (BatchNormal  (None, 19, 19, 256)  1024       ['block3a_expand_conv[0][0]']
#  ization)
#
#  block3a_expand_activation (Act  (None, 19, 19, 256)  0          ['block3a_expand_bn[0][0]']
#  ivation)
#
#  block3a_project_conv (Conv2D)  (None, 19, 19, 96)   24576       ['block3a_expand_activation[0][0]
#                                                                  ']
#
#  block3a_project_bn (BatchNorma  (None, 19, 19, 96)  384         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 19, 19, 384)  331776      ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 19, 19, 384)  1536       ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 19, 19, 384)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_project_conv (Conv2D)  (None, 19, 19, 96)   36864       ['block3b_expand_activation[0][0]
#                                                                  ']
#
#  block3b_project_bn (BatchNorma  (None, 19, 19, 96)  384         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_add (Add)              (None, 19, 19, 96)   0           ['block3b_project_bn[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2D)   (None, 19, 19, 384)  331776      ['block3b_add[0][0]']
#
#  block3c_expand_bn (BatchNormal  (None, 19, 19, 384)  1536       ['block3c_expand_conv[0][0]']
#  ization)
#
#  block3c_expand_activation (Act  (None, 19, 19, 384)  0          ['block3c_expand_bn[0][0]']
#  ivation)
#
#  block3c_project_conv (Conv2D)  (None, 19, 19, 96)   36864       ['block3c_expand_activation[0][0]
#                                                                  ']
#
#  block3c_project_bn (BatchNorma  (None, 19, 19, 96)  384         ['block3c_project_conv[0][0]']
#  lization)
#
#  block3c_add (Add)              (None, 19, 19, 96)   0           ['block3c_project_bn[0][0]',
#                                                                   'block3b_add[0][0]']
#
#  block3d_expand_conv (Conv2D)   (None, 19, 19, 384)  331776      ['block3c_add[0][0]']
#
#  block3d_expand_bn (BatchNormal  (None, 19, 19, 384)  1536       ['block3d_expand_conv[0][0]']
#  ization)
#
#  block3d_expand_activation (Act  (None, 19, 19, 384)  0          ['block3d_expand_bn[0][0]']
#  ivation)
#
#  block3d_project_conv (Conv2D)  (None, 19, 19, 96)   36864       ['block3d_expand_activation[0][0]
#                                                                  ']
#
#  block3d_project_bn (BatchNorma  (None, 19, 19, 96)  384         ['block3d_project_conv[0][0]']
#  lization)
#
#  block3d_add (Add)              (None, 19, 19, 96)   0           ['block3d_project_bn[0][0]',
#                                                                   'block3c_add[0][0]']
#
#  block3e_expand_conv (Conv2D)   (None, 19, 19, 384)  331776      ['block3d_add[0][0]']
#
#  block3e_expand_bn (BatchNormal  (None, 19, 19, 384)  1536       ['block3e_expand_conv[0][0]']
#  ization)
#
#  block3e_expand_activation (Act  (None, 19, 19, 384)  0          ['block3e_expand_bn[0][0]']
#  ivation)
#
#  block3e_project_conv (Conv2D)  (None, 19, 19, 96)   36864       ['block3e_expand_activation[0][0]
#                                                                  ']
#
#  block3e_project_bn (BatchNorma  (None, 19, 19, 96)  384         ['block3e_project_conv[0][0]']
#  lization)
#
#  block3e_add (Add)              (None, 19, 19, 96)   0           ['block3e_project_bn[0][0]',
#                                                                   'block3d_add[0][0]']
#
#  block3f_expand_conv (Conv2D)   (None, 19, 19, 384)  331776      ['block3e_add[0][0]']
#
#  block3f_expand_bn (BatchNormal  (None, 19, 19, 384)  1536       ['block3f_expand_conv[0][0]']
#  ization)
#
#  block3f_expand_activation (Act  (None, 19, 19, 384)  0          ['block3f_expand_bn[0][0]']
#  ivation)
#
#  block3f_project_conv (Conv2D)  (None, 19, 19, 96)   36864       ['block3f_expand_activation[0][0]
#                                                                  ']
#
#  block3f_project_bn (BatchNorma  (None, 19, 19, 96)  384         ['block3f_project_conv[0][0]']
#  lization)
#
#  block3f_add (Add)              (None, 19, 19, 96)   0           ['block3f_project_bn[0][0]',
#                                                                   'block3e_add[0][0]']
#
#  block3g_expand_conv (Conv2D)   (None, 19, 19, 384)  331776      ['block3f_add[0][0]']
#
#  block3g_expand_bn (BatchNormal  (None, 19, 19, 384)  1536       ['block3g_expand_conv[0][0]']
#  ization)
#
#  block3g_expand_activation (Act  (None, 19, 19, 384)  0          ['block3g_expand_bn[0][0]']
#  ivation)
#
#  block3g_project_conv (Conv2D)  (None, 19, 19, 96)   36864       ['block3g_expand_activation[0][0]
#                                                                  ']
#
#  block3g_project_bn (BatchNorma  (None, 19, 19, 96)  384         ['block3g_project_conv[0][0]']
#  lization)
#
#  block3g_add (Add)              (None, 19, 19, 96)   0           ['block3g_project_bn[0][0]',
#                                                                   'block3f_add[0][0]']
#
#  block4a_expand_conv (Conv2D)   (None, 19, 19, 384)  36864       ['block3g_add[0][0]']
#
#  block4a_expand_bn (BatchNormal  (None, 19, 19, 384)  1536       ['block4a_expand_conv[0][0]']
#  ization)
#
#  block4a_expand_activation (Act  (None, 19, 19, 384)  0          ['block4a_expand_bn[0][0]']
#  ivation)
#
#  block4a_dwconv2 (DepthwiseConv  (None, 10, 10, 384)  3456       ['block4a_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4a_bn (BatchNormalization  (None, 10, 10, 384)  1536       ['block4a_dwconv2[0][0]']
#  )
#
#  block4a_activation (Activation  (None, 10, 10, 384)  0          ['block4a_bn[0][0]']
#  )
#
#  block4a_se_squeeze (GlobalAver  (None, 384)         0           ['block4a_activation[0][0]']
#  agePooling2D)
#
#  block4a_se_reshape (Reshape)   (None, 1, 1, 384)    0           ['block4a_se_squeeze[0][0]']
#
#  block4a_se_reduce (Conv2D)     (None, 1, 1, 24)     9240        ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)     (None, 1, 1, 384)    9600        ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multiply)   (None, 10, 10, 384)  0           ['block4a_activation[0][0]',
#                                                                   'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv2D)  (None, 10, 10, 192)  73728       ['block4a_se_excite[0][0]']
#
#  block4a_project_bn (BatchNorma  (None, 10, 10, 192)  768        ['block4a_project_conv[0][0]']
#  lization)
#
#  block4b_expand_conv (Conv2D)   (None, 10, 10, 768)  147456      ['block4a_project_bn[0][0]']
#
#  block4b_expand_bn (BatchNormal  (None, 10, 10, 768)  3072       ['block4b_expand_conv[0][0]']
#  ization)
#
#  block4b_expand_activation (Act  (None, 10, 10, 768)  0          ['block4b_expand_bn[0][0]']
#  ivation)
#
#  block4b_dwconv2 (DepthwiseConv  (None, 10, 10, 768)  6912       ['block4b_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4b_bn (BatchNormalization  (None, 10, 10, 768)  3072       ['block4b_dwconv2[0][0]']
#  )
#
#  block4b_activation (Activation  (None, 10, 10, 768)  0          ['block4b_bn[0][0]']
#  )
#
#  block4b_se_squeeze (GlobalAver  (None, 768)         0           ['block4b_activation[0][0]']
#  agePooling2D)
#
#  block4b_se_reshape (Reshape)   (None, 1, 1, 768)    0           ['block4b_se_squeeze[0][0]']
#
#  block4b_se_reduce (Conv2D)     (None, 1, 1, 48)     36912       ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)     (None, 1, 1, 768)    37632       ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multiply)   (None, 10, 10, 768)  0           ['block4b_activation[0][0]',
#                                                                   'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv2D)  (None, 10, 10, 192)  147456      ['block4b_se_excite[0][0]']
#
#  block4b_project_bn (BatchNorma  (None, 10, 10, 192)  768        ['block4b_project_conv[0][0]']
#  lization)
#
#  block4b_add (Add)              (None, 10, 10, 192)  0           ['block4b_project_bn[0][0]',
#                                                                   'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2D)   (None, 10, 10, 768)  147456      ['block4b_add[0][0]']
#
#  block4c_expand_bn (BatchNormal  (None, 10, 10, 768)  3072       ['block4c_expand_conv[0][0]']
#  ization)
#
#  block4c_expand_activation (Act  (None, 10, 10, 768)  0          ['block4c_expand_bn[0][0]']
#  ivation)
#
#  block4c_dwconv2 (DepthwiseConv  (None, 10, 10, 768)  6912       ['block4c_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4c_bn (BatchNormalization  (None, 10, 10, 768)  3072       ['block4c_dwconv2[0][0]']
#  )
#
#  block4c_activation (Activation  (None, 10, 10, 768)  0          ['block4c_bn[0][0]']
#  )
#
#  block4c_se_squeeze (GlobalAver  (None, 768)         0           ['block4c_activation[0][0]']
#  agePooling2D)
#
#  block4c_se_reshape (Reshape)   (None, 1, 1, 768)    0           ['block4c_se_squeeze[0][0]']
#
#  block4c_se_reduce (Conv2D)     (None, 1, 1, 48)     36912       ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)     (None, 1, 1, 768)    37632       ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multiply)   (None, 10, 10, 768)  0           ['block4c_activation[0][0]',
#                                                                   'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv2D)  (None, 10, 10, 192)  147456      ['block4c_se_excite[0][0]']
#
#  block4c_project_bn (BatchNorma  (None, 10, 10, 192)  768        ['block4c_project_conv[0][0]']
#  lization)
#
#  block4c_add (Add)              (None, 10, 10, 192)  0           ['block4c_project_bn[0][0]',
#                                                                   'block4b_add[0][0]']
#
#  block4d_expand_conv (Conv2D)   (None, 10, 10, 768)  147456      ['block4c_add[0][0]']
#
#  block4d_expand_bn (BatchNormal  (None, 10, 10, 768)  3072       ['block4d_expand_conv[0][0]']
#  ization)
#
#  block4d_expand_activation (Act  (None, 10, 10, 768)  0          ['block4d_expand_bn[0][0]']
#  ivation)
#
#  block4d_dwconv2 (DepthwiseConv  (None, 10, 10, 768)  6912       ['block4d_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4d_bn (BatchNormalization  (None, 10, 10, 768)  3072       ['block4d_dwconv2[0][0]']
#  )
#
#  block4d_activation (Activation  (None, 10, 10, 768)  0          ['block4d_bn[0][0]']
#  )
#
#  block4d_se_squeeze (GlobalAver  (None, 768)         0           ['block4d_activation[0][0]']
#  agePooling2D)
#
#  block4d_se_reshape (Reshape)   (None, 1, 1, 768)    0           ['block4d_se_squeeze[0][0]']
#
#  block4d_se_reduce (Conv2D)     (None, 1, 1, 48)     36912       ['block4d_se_reshape[0][0]']
#
#  block4d_se_expand (Conv2D)     (None, 1, 1, 768)    37632       ['block4d_se_reduce[0][0]']
#
#  block4d_se_excite (Multiply)   (None, 10, 10, 768)  0           ['block4d_activation[0][0]',
#                                                                   'block4d_se_expand[0][0]']
#
#  block4d_project_conv (Conv2D)  (None, 10, 10, 192)  147456      ['block4d_se_excite[0][0]']
#
#  block4d_project_bn (BatchNorma  (None, 10, 10, 192)  768        ['block4d_project_conv[0][0]']
#  lization)
#
#  block4d_add (Add)              (None, 10, 10, 192)  0           ['block4d_project_bn[0][0]',
#                                                                   'block4c_add[0][0]']
#
#  block4e_expand_conv (Conv2D)   (None, 10, 10, 768)  147456      ['block4d_add[0][0]']
#
#  block4e_expand_bn (BatchNormal  (None, 10, 10, 768)  3072       ['block4e_expand_conv[0][0]']
#  ization)
#
#  block4e_expand_activation (Act  (None, 10, 10, 768)  0          ['block4e_expand_bn[0][0]']
#  ivation)
#
#  block4e_dwconv2 (DepthwiseConv  (None, 10, 10, 768)  6912       ['block4e_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4e_bn (BatchNormalization  (None, 10, 10, 768)  3072       ['block4e_dwconv2[0][0]']
#  )
#
#  block4e_activation (Activation  (None, 10, 10, 768)  0          ['block4e_bn[0][0]']
#  )
#
#  block4e_se_squeeze (GlobalAver  (None, 768)         0           ['block4e_activation[0][0]']
#  agePooling2D)
#
#  block4e_se_reshape (Reshape)   (None, 1, 1, 768)    0           ['block4e_se_squeeze[0][0]']
#
#  block4e_se_reduce (Conv2D)     (None, 1, 1, 48)     36912       ['block4e_se_reshape[0][0]']
#
#  block4e_se_expand (Conv2D)     (None, 1, 1, 768)    37632       ['block4e_se_reduce[0][0]']
#
#  block4e_se_excite (Multiply)   (None, 10, 10, 768)  0           ['block4e_activation[0][0]',
#                                                                   'block4e_se_expand[0][0]']
#
#  block4e_project_conv (Conv2D)  (None, 10, 10, 192)  147456      ['block4e_se_excite[0][0]']
#
#  block4e_project_bn (BatchNorma  (None, 10, 10, 192)  768        ['block4e_project_conv[0][0]']
#  lization)
#
#  block4e_add (Add)              (None, 10, 10, 192)  0           ['block4e_project_bn[0][0]',
#                                                                   'block4d_add[0][0]']
#
#  block4f_expand_conv (Conv2D)   (None, 10, 10, 768)  147456      ['block4e_add[0][0]']
#
#  block4f_expand_bn (BatchNormal  (None, 10, 10, 768)  3072       ['block4f_expand_conv[0][0]']
#  ization)
#
#  block4f_expand_activation (Act  (None, 10, 10, 768)  0          ['block4f_expand_bn[0][0]']
#  ivation)
#
# ...
#  block7d_expand_conv (Conv2D)   (None, 5, 5, 3840)   2457600     ['block7c_add[0][0]']
#
#  block7d_expand_bn (BatchNormal  (None, 5, 5, 3840)  15360       ['block7d_expand_conv[0][0]']
#  ization)
#
#  block7d_expand_activation (Act  (None, 5, 5, 3840)  0           ['block7d_expand_bn[0][0]']
#  ivation)
#
#  block7d_dwconv2 (DepthwiseConv  (None, 5, 5, 3840)  34560       ['block7d_expand_activation[0][0]
#  2D)                                                             ']
#
#  block7d_bn (BatchNormalization  (None, 5, 5, 3840)  15360       ['block7d_dwconv2[0][0]']
#  )
#
#  block7d_activation (Activation  (None, 5, 5, 3840)  0           ['block7d_bn[0][0]']
#  )
#
#  block7d_se_squeeze (GlobalAver  (None, 3840)        0           ['block7d_activation[0][0]']
#  agePooling2D)
#
#  block7d_se_reshape (Reshape)   (None, 1, 1, 3840)   0           ['block7d_se_squeeze[0][0]']
#
#  block7d_se_reduce (Conv2D)     (None, 1, 1, 160)    614560      ['block7d_se_reshape[0][0]']
#
#  block7d_se_expand (Conv2D)     (None, 1, 1, 3840)   618240      ['block7d_se_reduce[0][0]']
#
#  block7d_se_excite (Multiply)   (None, 5, 5, 3840)   0           ['block7d_activation[0][0]',
#                                                                   'block7d_se_expand[0][0]']
#
#  block7d_project_conv (Conv2D)  (None, 5, 5, 640)    2457600     ['block7d_se_excite[0][0]']
#
#  block7d_project_bn (BatchNorma  (None, 5, 5, 640)   2560        ['block7d_project_conv[0][0]']
#  lization)
#
#  block7d_add (Add)              (None, 5, 5, 640)    0           ['block7d_project_bn[0][0]',
#                                                                   'block7c_add[0][0]']
#
#  block7e_expand_conv (Conv2D)   (None, 5, 5, 3840)   2457600     ['block7d_add[0][0]']
#
#  block7e_expand_bn (BatchNormal  (None, 5, 5, 3840)  15360       ['block7e_expand_conv[0][0]']
#  ization)
#
#  block7e_expand_activation (Act  (None, 5, 5, 3840)  0           ['block7e_expand_bn[0][0]']
#  ivation)
#
#  block7e_dwconv2 (DepthwiseConv  (None, 5, 5, 3840)  34560       ['block7e_expand_activation[0][0]
#  2D)                                                             ']
#
#  block7e_bn (BatchNormalization  (None, 5, 5, 3840)  15360       ['block7e_dwconv2[0][0]']
#  )
#
#  block7e_activation (Activation  (None, 5, 5, 3840)  0           ['block7e_bn[0][0]']
#  )
#
#  block7e_se_squeeze (GlobalAver  (None, 3840)        0           ['block7e_activation[0][0]']
#  agePooling2D)
#
#  block7e_se_reshape (Reshape)   (None, 1, 1, 3840)   0           ['block7e_se_squeeze[0][0]']
#
#  block7e_se_reduce (Conv2D)     (None, 1, 1, 160)    614560      ['block7e_se_reshape[0][0]']
#
#  block7e_se_expand (Conv2D)     (None, 1, 1, 3840)   618240      ['block7e_se_reduce[0][0]']
#
#  block7e_se_excite (Multiply)   (None, 5, 5, 3840)   0           ['block7e_activation[0][0]',
#                                                                   'block7e_se_expand[0][0]']
#
#  block7e_project_conv (Conv2D)  (None, 5, 5, 640)    2457600     ['block7e_se_excite[0][0]']
#
#  block7e_project_bn (BatchNorma  (None, 5, 5, 640)   2560        ['block7e_project_conv[0][0]']
#  lization)
#
#  block7e_add (Add)              (None, 5, 5, 640)    0           ['block7e_project_bn[0][0]',
#                                                                   'block7d_add[0][0]']
#
#  block7f_expand_conv (Conv2D)   (None, 5, 5, 3840)   2457600     ['block7e_add[0][0]']
#
#  block7f_expand_bn (BatchNormal  (None, 5, 5, 3840)  15360       ['block7f_expand_conv[0][0]']
#  ization)
#
#  block7f_expand_activation (Act  (None, 5, 5, 3840)  0           ['block7f_expand_bn[0][0]']
#  ivation)
#
#  block7f_dwconv2 (DepthwiseConv  (None, 5, 5, 3840)  34560       ['block7f_expand_activation[0][0]
#  2D)                                                             ']
#
#  block7f_bn (BatchNormalization  (None, 5, 5, 3840)  15360       ['block7f_dwconv2[0][0]']
#  )
#
#  block7f_activation (Activation  (None, 5, 5, 3840)  0           ['block7f_bn[0][0]']
#  )
#
#  block7f_se_squeeze (GlobalAver  (None, 3840)        0           ['block7f_activation[0][0]']
#  agePooling2D)
#
#  block7f_se_reshape (Reshape)   (None, 1, 1, 3840)   0           ['block7f_se_squeeze[0][0]']
#
#  block7f_se_reduce (Conv2D)     (None, 1, 1, 160)    614560      ['block7f_se_reshape[0][0]']
#
#  block7f_se_expand (Conv2D)     (None, 1, 1, 3840)   618240      ['block7f_se_reduce[0][0]']
#
#  block7f_se_excite (Multiply)   (None, 5, 5, 3840)   0           ['block7f_activation[0][0]',
#                                                                   'block7f_se_expand[0][0]']
#
#  block7f_project_conv (Conv2D)  (None, 5, 5, 640)    2457600     ['block7f_se_excite[0][0]']
#
#  block7f_project_bn (BatchNorma  (None, 5, 5, 640)   2560        ['block7f_project_conv[0][0]']
#  lization)
#
#  block7f_add (Add)              (None, 5, 5, 640)    0           ['block7f_project_bn[0][0]',
#                                                                   'block7e_add[0][0]']
#
#  block7g_expand_conv (Conv2D)   (None, 5, 5, 3840)   2457600     ['block7f_add[0][0]']
#
#  block7g_expand_bn (BatchNormal  (None, 5, 5, 3840)  15360       ['block7g_expand_conv[0][0]']
#  ization)
#
#  block7g_expand_activation (Act  (None, 5, 5, 3840)  0           ['block7g_expand_bn[0][0]']
#  ivation)
#
#  block7g_dwconv2 (DepthwiseConv  (None, 5, 5, 3840)  34560       ['block7g_expand_activation[0][0]
#  2D)                                                             ']
#
#  block7g_bn (BatchNormalization  (None, 5, 5, 3840)  15360       ['block7g_dwconv2[0][0]']
#  )
#
#  block7g_activation (Activation  (None, 5, 5, 3840)  0           ['block7g_bn[0][0]']
#  )
#
#  block7g_se_squeeze (GlobalAver  (None, 3840)        0           ['block7g_activation[0][0]']
#  agePooling2D)
#
#  block7g_se_reshape (Reshape)   (None, 1, 1, 3840)   0           ['block7g_se_squeeze[0][0]']
#
#  block7g_se_reduce (Conv2D)     (None, 1, 1, 160)    614560      ['block7g_se_reshape[0][0]']
#
#  block7g_se_expand (Conv2D)     (None, 1, 1, 3840)   618240      ['block7g_se_reduce[0][0]']
#
#  block7g_se_excite (Multiply)   (None, 5, 5, 3840)   0           ['block7g_activation[0][0]',
#                                                                   'block7g_se_expand[0][0]']
#
#  block7g_project_conv (Conv2D)  (None, 5, 5, 640)    2457600     ['block7g_se_excite[0][0]']
#
#  block7g_project_bn (BatchNorma  (None, 5, 5, 640)   2560        ['block7g_project_conv[0][0]']
#  lization)
#
#  block7g_add (Add)              (None, 5, 5, 640)    0           ['block7g_project_bn[0][0]',
#                                                                   'block7f_add[0][0]']
#
#  top_conv (Conv2D)              (None, 5, 5, 1280)   819200      ['block7g_add[0][0]']
#
#  top_bn (BatchNormalization)    (None, 5, 5, 1280)   5120        ['top_conv[0][0]']
#
#  top_activation (Activation)    (None, 5, 5, 1280)   0           ['top_bn[0][0]']
#
#  flatten (Flatten)              (None, 32000)        0           ['top_activation[0][0]']
#
#  dense (Dense)                  (None, 16)           512016      ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 118,258,864
# Trainable params: 512,016
# Non-trainable params: 117,746,848
# __________________________________________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
epoch = 10
history = model.fit(train_generator,
                    steps_per_epoch = None,
                    epochs = epoch,
                    validation_data = validation_generator,
                    validation_steps = None
                    )
# Out:
# Epoch 1/10
#  47/228 [=====>........................] - ETA: 43:04 - loss: 7.2156 - accuracy: 0.1197
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# 228/228 [==============================] - 3724s 16s/step - loss: 4.6936 - accuracy: 0.1373 - val_loss: 5.1601 - val_accuracy: 0.1432
# Epoch 2/10
# 228/228 [==============================] - 2701s 12s/step - loss: 3.8686 - accuracy: 0.1866 - val_loss: 4.4287 - val_accuracy: 0.1088
# Epoch 3/10
# 228/228 [==============================] - 2778s 12s/step - loss: 3.8044 - accuracy: 0.1923 - val_loss: 3.7146 - val_accuracy: 0.1856
# Epoch 4/10
# 228/228 [==============================] - 2756s 12s/step - loss: 3.6274 - accuracy: 0.2122 - val_loss: 2.8982 - val_accuracy: 0.2405
# Epoch 5/10
# 228/228 [==============================] - 2840s 12s/step - loss: 3.3766 - accuracy: 0.2291 - val_loss: 3.6471 - val_accuracy: 0.2245
# Epoch 6/10
# 228/228 [==============================] - 2817s 12s/step - loss: 3.5417 - accuracy: 0.2311 - val_loss: 4.3769 - val_accuracy: 0.2257
# Epoch 7/10
# 228/228 [==============================] - 2777s 12s/step - loss: 3.4711 - accuracy: 0.2378 - val_loss: 3.6305 - val_accuracy: 0.2623
# Epoch 8/10
# 228/228 [==============================] - 2784s 12s/step - loss: 3.3333 - accuracy: 0.2514 - val_loss: 4.2342 - val_accuracy: 0.2005
# Epoch 9/10
# 228/228 [==============================] - 2836s 12s/step - loss: 3.5531 - accuracy: 0.2484 - val_loss: 3.9305 - val_accuracy: 0.2543
# Epoch 10/10
# 228/228 [==============================] - 2775s 12s/step - loss: 3.4365 - accuracy: 0.2627 - val_loss: 3.7482 - val_accuracy: 0.2108

# %%
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

train_loss = history.history['loss']
val_loss = history.history['val_loss']

fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(12, 10))

ax[0].set_title('Training Accuracy vs. Epochs')
ax[0].plot(train_accuracy, 'o-', label='Train Accuracy')
ax[0].plot(val_accuracy, 'o-', label='Validation Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='best')

ax[1].set_title('Training/Validation Loss vs. Epochs')
ax[1].plot(train_loss, 'o-', label='Train Loss')
ax[1].plot(val_loss, 'o-', label='Validation Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='best')

plt.tight_layout()
plt.show()

# %%
test_dataset = '/content/drive/MyDrive/Poribohon-BD/test/'

# %%
test_datagen = ImageDataGenerator(rescale=1.0/255)

test_generator = test_datagen.flow_from_directory(test_dataset,
                                                 shuffle=False,
                                                 batch_size=BATCH_SIZE,
                                                 target_size = (IMG_WIDTH, IMG_HEIGHT),
                                                 class_mode='categorical')
# Out:
# Found 910 images belonging to 16 classes.

# %%
predictions = model.predict(test_generator)

# %%
test_loss, test_accuracy = model.evaluate(test_generator, batch_size=BATCH_SIZE)
print(f"Test Loss:     {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# 29/29 [==============================] - 293s 10s/step - loss: 3.4736 - accuracy: 0.2231
# Test Loss:     3.4735512733459473
# Test Accuracy: 0.2230769246816635

# %%
y_pred = np.argmax(predictions, axis=1)
y_true = test_generator.classes

# %%
cf_mtx = confusion_matrix(y_true, y_pred)

group_counts = ["{0:0.0f}".format(value) for value in cf_mtx.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_mtx.flatten()/np.sum(cf_mtx)]
box_labels = [f"{v1}\n({v2})" for v1, v2 in zip(group_counts, group_percentages)]
box_labels = np.asarray(box_labels).reshape(16, 16)

plt.figure(figsize = (30, 15))
sns.heatmap(cf_mtx, xticklabels=labels.values(), yticklabels=labels.values(),
           cmap="YlGnBu", fmt="", annot=box_labels)
plt.xlabel('Predicted Classes')
plt.ylabel('True Classes')
plt.show()

# %%
print(classification_report(y_true, y_pred, target_names=labels.values()))
# Out:
#                       precision    recall  f1-score   support
#
#              Bicycle       1.00      0.04      0.08        70
#                 Bike       0.57      0.33      0.41        86
#                 Boat       0.19      0.89      0.31        61
#                  Bus       0.00      0.00      0.00        45
#                  Car       0.31      0.49      0.38        70
#                  Cng       0.14      0.32      0.19        53
#            Easy-bike       0.14      0.13      0.13        61
#           Horse-cart       0.00      0.00      0.00        25
#               Launch       1.00      0.06      0.11        66
#               Leguna       0.00      0.00      0.00        21
# Multi-class Vehicles       0.22      0.07      0.10        91
#             Rickshaw       0.12      0.14      0.13        49
#              Tractor       0.20      0.53      0.29        55
#                Truck       0.21      0.15      0.17        73
#                  Van       1.00      0.03      0.06        61
#          Wheelbarrow       0.00      0.00      0.00        23
#
#             accuracy                           0.22       910
#            macro avg       0.32      0.20      0.15       910
#         weighted avg       0.38      0.22      0.18       910
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
